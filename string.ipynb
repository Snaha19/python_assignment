# %%
## 6
s=input("enter any string")
a=len(s)
print(a)
s1=s[:((a//2))].upper()+s[((a//2)):]
print(s1)
# Out:
# enter any string bambooo
# 7
# BAMbooo

# %%
s=input("enter any string")
for item in range(len(s)):
    print(chr(ord(s[item])))
    #print(ord(s[item]))
#print(
# Out:
# enter any string bhgdjgwj
# b
# h
# g
# d
# j
# g
# w
# j

# %%
# 7
s=input("enter any string")
res=''
for i in s.split():
    res+=i[:-1].capitalize()+i[-1].capitalize()+' '
print(res)
# Out:
# enter any string i am a good girl
# I AM A GooD GirL
